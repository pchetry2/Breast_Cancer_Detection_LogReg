# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/priyankachetry/Documents/Hands-on Projects/Breast_Cancer_Detection/codes'

# %%
df = pd.read_csv('../data/breast_cancer_wisconsin_data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
len(df), len(df.columns)
# Out:
# (569, 33)

# %% [markdown]
# ## No of Rows & Columns

# %%
rows = len(df.axes[0])
columns = len(df.axes[1])

#Print
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 569
# Number of columns: 33

# %% [markdown]
# ## No. of Continuous & Categorical values

# %%
#Total no. of data types

df.dtypes.value_counts()
# Out:
# float64    31
# int64       1
# object      1
# Name: count, dtype: int64

# %%
#Continuous & categorical features
continuous = df.select_dtypes(include='number')
len(continuous)
print(f"Continuous : {len(continuous)}")

categorical = df.select_dtypes(include='object')
len(categorical)
print(f"Categorical : {len(categorical)}")
# Out:
# Continuous : 569
# Categorical : 569

# %% [markdown]
# ## Missing Rate

# %%
# missing values for all columns
df.isnull()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# for Missing Rate for all columns
df_missing_rate = (df.isnull().sum()*100/len(df)).reset_index()

# %%
df_missing_rate = df_missing_rate.rename(columns={'index': 'variable_name', 0: 'missing_rate'})

# %%
df_missing_rate.columns
# Out:
# Index(['variable_name', 'missing_rate'], dtype='object')

# %%
df_missing_rate
# Out:
#               variable_name  missing_rate
# 0                        id           0.0
# 1                 diagnosis           0.0
# 2               radius_mean           0.0
# 3              texture_mean           0.0
# 4            perimeter_mean           0.0
# 5                 area_mean           0.0
# 6           smoothness_mean           0.0
# 7          compactness_mean           0.0
# 8            concavity_mean           0.0
# 9       concave points_mean           0.0
# 10            symmetry_mean           0.0
# 11   fractal_dimension_mean           0.0
# 12                radius_se           0.0
# 13               texture_se           0.0
# 14             perimeter_se           0.0
# 15                  area_se           0.0
# 16            smoothness_se           0.0
# 17           compactness_se           0.0
# 18             concavity_se           0.0
# 19        concave points_se           0.0
# 20              symmetry_se           0.0
# ...

# %%
#Drop high missing rate feature
new_df = df.drop('Unnamed: 32', axis=1)

# %%
new_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
new_df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %% [markdown]
# ## Convert Categorical into Numeric label

# %%
new_df['diagnosis'] = new_df.diagnosis.replace({"M":1, "B":0})
# Out:
# /var/folders/q9/pltwnf513ns14qtthspkrphm0000gn/T/ipykernel_10638/666985515.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df['diagnosis'] = new_df.diagnosis.replace({"M":1, "B":0})

# %%
new_df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## event rate

# %%
new_df.diagnosis.mean()
# Out:
# 0.37258347978910367

# %% [markdown]
# ## check correlation for continuous feature with the output variables using pearson correlation coeff

# %%
correlation_matrix = new_df.corr()

# %%
correlation_matrix
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
#correlation for diagnosis with each feature

correlation_with_target = correlation_matrix["diagnosis"].drop("diagnosis")

# %%
corr_with_target = abs(correlation_matrix["diagnosis"])

# %%
corr_with_target
# Out:
# id                         0.039769
# diagnosis                  1.000000
# radius_mean                0.730029
# texture_mean               0.415185
# perimeter_mean             0.742636
# area_mean                  0.708984
# smoothness_mean            0.358560
# compactness_mean           0.596534
# concavity_mean             0.696360
# concave points_mean        0.776614
# symmetry_mean              0.330499
# fractal_dimension_mean     0.012838
# radius_se                  0.567134
# texture_se                 0.008303
# perimeter_se               0.556141
# area_se                    0.548236
# smoothness_se              0.067016
# compactness_se             0.292999
# concavity_se               0.253730
# concave points_se          0.408042
# symmetry_se                0.006522
# fractal_dimension_se       0.077972
# radius_worst               0.776454
# texture_worst              0.456903
# perimeter_worst            0.782914
# area_worst                 0.733825
# ...

# %%
#bar plot - 
corr_with_target.plot(kind='bar', color='skyblue')
plt.title('Correlation of Features with Diagnosis')
plt.ylabel('Correlation coefficient')
plt.xlabel('Features')
plt.show()

# %% [markdown]
# ## Dropping very low correlated features

# %%
cols
# Out:
# ['id',
#  'fractal_dimension_mean',
#  'texture_se',
#  'smoothness_se',
#  'symmetry_se',
#  'fractal_dimension_se']

# %%
new_df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
#Selecting least correlated features
least_corr_features = corr_with_target[corr_with_target<0.1]

# list of irelevant_features
cols = list([i for i in least_corr_features.index])

#Dropping irelevant_features
dropped_cols= new_df.drop(cols, axis=1)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
new_df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
new_df['diagnosis'].isnull() #checking missing value for target variable
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Name: diagnosis, Length: 569, dtype: bool

# %%
#check missing value for independent features

new_features = new_df.drop('diagnosis', axis=1)

# %%
new_features
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
new_features.isnull().sum()
# Out:
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#Identifying Input & Target variable

X = new_features
y = new_df.diagnosis

# %%
#split the data -make stratifying sampling : uniform selection -in classification 

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.3, random_state = 42)

# %%
#Feature Scaling

scaler = StandardScaler()

#Fit the scaler to the training data and transform

X_train = scaler.fit_transform(X_train)

# Tranform the scaler into testing data

X_test = scaler.transform(X_test)

# %% [markdown]
# ## Build & Train the Model

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# saving the data 

import pickle

with open('logreg_model.pickle', 'wb') as handle:
    pickle.dump(model, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('logreg_model.pickle', 'rb') as handle:
    model = pickle.load(handle)

# %% [markdown]
# ## Evaluate the model

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy:{accuracy*100:.2f}%")
# Out:
# Accuracy:98.25%

# %%
# evaluate the model
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[106   2]
#  [  1  62]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       108
#            1       0.97      0.98      0.98        63
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# ## Higher precision indicates fewer false positives
# ## Higher recall indicates fewer false negatives

# %%
# Predict the probabilities of the test set
proba = model.predict_proba(X_test)

# Print the predicted probabilities
print(proba)
# Out:
# [[8.84669220e-01 1.15330780e-01]
#  [1.55827657e-05 9.99984417e-01]
#  [3.49868261e-03 9.96501317e-01]
#  [9.99502897e-01 4.97103000e-04]
#  [9.99927367e-01 7.26332673e-05]
#  [2.53776999e-10 1.00000000e+00]
#  [4.10813472e-09 9.99999996e-01]
#  [4.43581507e-02 9.55641849e-01]
#  [5.84085611e-01 4.15914389e-01]
#  [9.99270384e-01 7.29616008e-04]
#  [9.47524000e-01 5.24760002e-02]
#  [1.46899519e-02 9.85310048e-01]
#  [9.93437958e-01 6.56204238e-03]
#  [1.83825205e-01 8.16174795e-01]
#  [9.97497148e-01 2.50285160e-03]
#  [1.50047974e-03 9.98499520e-01]
#  [9.97981006e-01 2.01899373e-03]
#  [9.99990533e-01 9.46670382e-06]
#  [9.99999281e-01 7.18684557e-07]
#  [1.82602669e-06 9.99998174e-01]
#  [9.24752225e-01 7.52477746e-02]
#  [9.89573223e-01 1.04267773e-02]
#  [1.00703138e-08 9.99999990e-01]
#  [9.99918633e-01 8.13672637e-05]
#  [9.98707234e-01 1.29276576e-03]
#  [9.99625726e-01 3.74274127e-04]
#  [9.98540001e-01 1.45999943e-03]
#  [9.92125390e-01 7.87460997e-03]
# ...

# %%
proba
# Out:
# array([[8.84669220e-01, 1.15330780e-01],
#        [1.55827657e-05, 9.99984417e-01],
#        [3.49868261e-03, 9.96501317e-01],
#        [9.99502897e-01, 4.97103000e-04],
#        [9.99927367e-01, 7.26332673e-05],
#        [2.53776999e-10, 1.00000000e+00],
#        [4.10813472e-09, 9.99999996e-01],
#        [4.43581507e-02, 9.55641849e-01],
#        [5.84085611e-01, 4.15914389e-01],
#        [9.99270384e-01, 7.29616008e-04],
#        [9.47524000e-01, 5.24760002e-02],
#        [1.46899519e-02, 9.85310048e-01],
#        [9.93437958e-01, 6.56204238e-03],
#        [1.83825205e-01, 8.16174795e-01],
#        [9.97497148e-01, 2.50285160e-03],
#        [1.50047974e-03, 9.98499520e-01],
#        [9.97981006e-01, 2.01899373e-03],
#        [9.99990533e-01, 9.46670382e-06],
#        [9.99999281e-01, 7.18684557e-07],
#        [1.82602669e-06, 9.99998174e-01],
#        [9.24752225e-01, 7.52477746e-02],
#        [9.89573223e-01, 1.04267773e-02],
#        [1.00703138e-08, 9.99999990e-01],
# ...

# %%
proba_malignant = [x[1] for x in proba]
proba_benign = [x[0] for x in proba]

# %%
proba_benign
# Out:
# [0.884669219621437,
#  1.5582765700905554e-05,
#  0.0034986826090694922,
#  0.9995028969995982,
#  0.9999273667327357,
#  2.5377699941486753e-10,
#  4.108134721292345e-09,
#  0.044358150687774045,
#  0.5840856106513392,
#  0.9992703839920452,
#  0.947523999832219,
#  0.01468995191134459,
#  0.9934379576207713,
#  0.18382520474831998,
#  0.9974971483957177,
#  0.0015004797440860695,
#  0.9979810062679403,
#  0.9999905332961825,
#  0.9999992813154427,
#  1.8260266881897635e-06,
#  0.9247522253727523,
#  0.9895732226848848,
#  1.0070313805066178e-08,
#  0.999918632736329,
#  0.9987072342417153,
#  0.999625725872549,
#  0.9985400005680037,
#  0.9921253900337367,
#  0.9964418092196181,
#  2.046076763240201e-05,
#  0.9991317567469287,
#  0.999823419875113,
#  0.99845311346297,
#  0.9937426174552951,
#  0.9998514157991178,
#  0.9969696716305992,
#  0.08440234046792872,
#  0.9958264539540513,
#  0.00013307901346470974,
#  0.9596917678992345,
#  0.9999084285792551,
#  0.0005246227154489524,
# ...

# %%
y_test_act = pd.DataFrame({'diagnosis': y_test})
y_test_act.index = range(len(y_test_act))

# %%
y_test_proba = pd.DataFrame({'probability': proba_malignant})
y_test_proba.index = range(len(y_test_proba))

# %%
df_to_compare = pd.concat([y_test_act, y_test_proba], ignore_index=False, axis=1)

# %%
df_to_compare
# Out:
#      diagnosis  probability
# 0            0     0.115331
# 1            1     0.999984
# 2            1     0.996501
# 3            0     0.000497
# 4            0     0.000073
# ..         ...          ...
# 166          0     0.000888
# 167          0     0.329858
# 168          0     0.000023
# 169          1     0.978206
# 170          0     0.017965
#
# [171 rows x 2 columns]

# %%
df_to_compare.diagnosis.mean(), df_to_compare.probability.mean()
# Out:
# (0.3684210526315789, 0.37903158597459075)

# %%
# Create equal population 10 buckets for probability

df_to_compare['bucket'] = pd.qcut(df_to_compare.probability, 10)

# %%
df_to_compare
# Out:
#      diagnosis  probability                       bucket
# 0            0     0.115331         (0.026411, 0.261087]
# 1            1     0.999984         (0.999578, 0.999999]
# 2            1     0.996501          (0.98531, 0.999578]
# 3            0     0.000497    (0.000380311, 0.00149608]
# 4            0     0.000073  (-8.37375e-07, 8.13673e-05]
# ..         ...          ...                          ...
# 166          0     0.000888    (0.000380311, 0.00149608]
# 167          0     0.329858          (0.261087, 0.98531]
# 168          0     0.000023  (-8.37375e-07, 8.13673e-05]
# 169          1     0.978206          (0.261087, 0.98531]
# 170          0     0.017965       (0.00625738, 0.026411]
#
# [171 rows x 3 columns]

# %% [markdown]
# ## Visualization

# %%
plt.hist(df_to_compare[df_to_compare.diagnosis == 0].probability)
# Out:
# (array([97.,  1.,  3.,  1.,  3.,  1.,  1.,  0.,  0.,  1.]),
#  array([1.62625228e-07, 7.51865166e-02, 1.50372871e-01, 2.25559225e-01,
#         3.00745579e-01, 3.75931933e-01, 4.51118287e-01, 5.26304641e-01,
#         6.01490995e-01, 6.76677349e-01, 7.51863703e-01]),
#  <BarContainer object of 10 artists>)

# %%
df_to_compare.groupby(by='bucket').diagnosis.mean().reset_index()
# Out:
# /var/folders/q9/pltwnf513ns14qtthspkrphm0000gn/T/ipykernel_10638/680426657.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_to_compare.groupby(by='bucket').diagnosis.mean().reset_index()
#                         bucket  diagnosis
# 0  (-8.37375e-07, 8.13673e-05]   0.000000
# 1   (8.13673e-05, 0.000380311]   0.000000
# 2    (0.000380311, 0.00149608]   0.000000
# 3     (0.00149608, 0.00625738]   0.000000
# 4       (0.00625738, 0.026411]   0.000000
# 5         (0.026411, 0.261087]   0.058824
# 6          (0.261087, 0.98531]   0.625000
# 7          (0.98531, 0.999578]   1.000000
# 8         (0.999578, 0.999999]   1.000000
# 9              (0.999999, 1.0]   1.000000

# %%
df_to_compare.groupby(by='bucket').diagnosis.mean().reset_index()
# Out:
# /var/folders/q9/pltwnf513ns14qtthspkrphm0000gn/T/ipykernel_10638/2303830104.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_to_compare.groupby(by='bucket').diagnosis.mean().reset_index()
#                         bucket  diagnosis
# 0  (-8.37375e-07, 8.13673e-05]   0.000000
# 1   (8.13673e-05, 0.000380311]   0.000000
# 2    (0.000380311, 0.00149608]   0.000000
# 3     (0.00149608, 0.00625738]   0.000000
# 4       (0.00625738, 0.026411]   0.000000
# 5         (0.026411, 0.261087]   0.058824
# 6          (0.261087, 0.98531]   0.625000
# 7          (0.98531, 0.999578]   1.000000
# 8         (0.999578, 0.999999]   1.000000
# 9              (0.999999, 1.0]   1.000000

# %%
plt.hist(df_to_compare[df_to_compare.diagnosis == 1].probability)
# Out:
# (array([ 1.,  0.,  0.,  0.,  1.,  1.,  0.,  0.,  3., 57.]),
#  array([0.07524777, 0.167723  , 0.26019822, 0.35267344, 0.44514866,
#         0.53762389, 0.63009911, 0.72257433, 0.81504955, 0.90752478,
#         1.        ]),
#  <BarContainer object of 10 artists>)
